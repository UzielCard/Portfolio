# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("accidents.csv", sep=";")

# %%
df.head()
# Out:
#          DATE   TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/26/2018  12:12     BRONX   10454.0  40.808987 -73.911316
# 1  09/25/2018  16:30  BROOKLYN   11236.0  40.636005 -73.912510
# 2  08/22/2019  19:30    QUEENS   11101.0  40.755490 -73.939530
# 3  09/23/2018  13:10    QUEENS   11367.0        NaN        NaN
# 4  08/20/2019  22:40     BRONX   10468.0  40.868336 -73.901270
#
#                      ON STREET NAME  NUMBER OF PEDESTRIANS INJURED  \
# 0                               NaN                              0
# 1  FLATLANDS AVENUE                                              1
# 2                               NaN                              0
# 3  MAIN STREET                                                   0
# 4                               NaN                              0
#
#    NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  ...  \
# 0                             0                          0  ...
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'ON STREET NAME', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df.dtypes
# Out:
# DATE                              object
# TIME                              object
# BOROUGH                           object
# ZIP CODE                         float64
# LATITUDE                         float64
# LONGITUDE                        float64
# ON STREET NAME                    object
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# COLLISION_ID                       int64
# VEHICLE TYPE CODE 1               object
# VEHICLE TYPE CODE 2               object
# VEHICLE TYPE CODE 3               object
# VEHICLE TYPE CODE 4               object
# ...

# %%
df.isna().sum()
# Out:
# DATE                                  0
# TIME                                  0
# BOROUGH                               0
# ZIP CODE                             70
# LATITUDE                           6978
# LONGITUDE                          6978
# ON STREET NAME                    84604
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1       884
# CONTRIBUTING FACTOR VEHICLE 2     40008
# CONTRIBUTING FACTOR VEHICLE 3    225450
# CONTRIBUTING FACTOR VEHICLE 4    235666
# CONTRIBUTING FACTOR VEHICLE 5    237730
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1                1721
# VEHICLE TYPE CODE 2               55590
# VEHICLE TYPE CODE 3              226221
# VEHICLE TYPE CODE 4              235806
# ...

# %%
df.describe()
# Out:
#             ZIP CODE       LATITUDE      LONGITUDE  \
# count  238452.000000  231544.000000  231544.000000
# mean    10865.578838      40.656873     -73.797699
# std       546.056571       1.632850       2.961521
# min     10000.000000       0.000000     -74.253930
# 25%     10452.000000      40.666750     -73.973860
# 50%     11208.000000      40.717007     -73.922770
# 75%     11354.000000      40.765715     -73.864890
# max     11697.000000      40.912884       0.000000
#
#        NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# count                  238522.000000                 238522.000000
# mean                        0.054523                      0.000532
# std                         0.237834                      0.023250
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# ...

# %%
df["ZIP CODE"].fillna(0, inplace = True)

# %%
df["ZIP CODE"] = df["ZIP CODE"].astype("int")

# %%
df.dtypes
# Out:
# DATE                              object
# TIME                              object
# BOROUGH                           object
# ZIP CODE                           int64
# LATITUDE                         float64
# LONGITUDE                        float64
# ON STREET NAME                    object
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# COLLISION_ID                       int64
# VEHICLE TYPE CODE 1               object
# VEHICLE TYPE CODE 2               object
# VEHICLE TYPE CODE 3               object
# VEHICLE TYPE CODE 4               object
# ...

# %%
streets = df['ON STREET NAME'].unique().tolist()
streets = sorted(streets, key=lambda x: str(x))
len(streets)
# Out:
# 5222

# %%
streets = df['ON STREET NAME']
streets = [str(i).strip().lower() for i in streets]
streets = list(set(streets))
streets = sorted(streets, key=lambda x: str(x))
len(streets)
# Out:
# 4874

# %%
streets
# Out:
# ['1 avenue',
#  '1 place',
#  '1 street',
#  '10 ave',
#  '10 avenue',
#  '10 street',
#  '100 avenue',
#  '100 drive',
#  '100 street',
#  '101 avenue',
#  '101 road',
#  '101 street',
#  '102 avenue',
#  '102 road',
#  '102 street',
#  '103 avenue',
#  '103 drive',
#  '103 road',
#  '103 street',
#  '104 avenue',
#  '104 road',
#  '104 street',
#  '105 avenue',
#  '105 street',
#  '106 avenue',
#  '106 street',
#  '107 avenue',
#  '107 street',
#  '108 avenue',
#  '108 drive',
#  '108 road',
#  '108 street',
#  '109 avenue',
#  '109 road',
#  '109 street',
#  '10th ave',
#  '10th avenue',
#  '10th street',
#  '11 ave',
#  '11 avenue',
#  '11 place',
#  '11 street',
#  '110 avenue',
#  '110 road',
#  '110 street',
#  '111 avenue',
#  '111 road',
#  '111 street',
#  '112 avenue',
#  '112 place',
#  '112 road',
#  '112 street',
#  '113 avenue',
#  '113 drive',
#  '113 street',
#  '114 avenue',
#  '114 drive',
#  '114 place',
#  '114 road',
#  '114 street',
#  '115 avenue',
# ...

# %%
import re

# %%
a = ' '.join(streets)

# %%
b = re.split(r' ',a)

# %%
c = list(set(b))
c = sorted(c, key=lambda x: str(x))
len(c)
# Out:
# 2821

# %%
d = re.findall(r'\d+th', a)

# %%
e = [re.sub(r'(\d+)th', r'\1', i) for i in b]

# %%
f = list(set(e))
f = sorted(f, key=lambda x: str(x))
len(f)
# Out:
# 2774

# %%
g = df['ON STREET NAME']
len(g)
# Out:
# 238522

# %%
h = [str(i).strip().lower() for i in g]
j = [re.sub(r'(\d+)th', r'\1', i) for i in h]
len(j)
# Out:
# 238522

# %%
k = []
for i in df['ON STREET NAME']:
    l = str(i).strip().lower()
    l = re.sub(r'(\d+)th', r'\1', l)
    k.append(l)

len(k)
# Out:
# 238522

# %%
m = ' '.join(k)

# %%
n = re.findall(r'\bave\b', m)

# %%
n = list(set(n))
n = sorted(n, key=len)
n
# Out:
# ['ave']

# %% [markdown]
# Ideas Storytelling
#
# Injuries, deaths
# Where, when
